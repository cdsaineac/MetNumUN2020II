# %% [markdown]
# # **Data Science Fabric: Taylor Series Expansion with Python**

# %% [markdown]
# <img src="https://raw.githubusercontent.com/jortizsi/MetNumUN2020II/master/Grafica3Taylor.png"/>

# %%
from sympy import series, Symbol
from sympy.functions import sin, cos, exp
from sympy.plotting import plot
import matplotlib.pyplot as plt
# %matplotlib inline

plt.rcParams['figure.figsize'] = 13,10
plt.rcParams['lines.linewidth'] = 2

# %%
# Define symbol
x = Symbol('x')

# %%
# Function for Taylor Series Expansion

def taylor(function, x0, n):
    """
    Parameter "function" is our function which we want to approximate
    "x0" is the point where to approximate
    "n" is the order of approximation
    """
    return function.series(x,x0,n).removeO()

# %% [markdown]
# While defining "taylor" function, in return statement I used **".removeO()"** method. This method is used in series expansion to remove $O(x^n)$ term, which is Landau order term at $x=0$ and not to be confused with big $O$ notation used in computer science, which generally represents the Landau order term at $x=∞$.
#
# We can do sin(x), cos(x), and e(x) expansion by using Sympy.

# %%
print('sin(x) =', taylor(sin(x), 0, 4))

print('cos(x) =', taylor(cos(x), 0, 4))

print('e(x) =', taylor(exp(x), 0, 4))
# Out:
# sin(x) = -x**3/6 + x
# cos(x) = -x**2/2 + 1
# e(x) = x**3/6 + x**2/2 + x + 1

# %% [markdown]
# That's not all. We can evaluate these functions at any point. For instance as we did above for $x=1$

# %%
print('sin(1) =', taylor(sin(x), 0, 4).subs(x,1))

print('cos(1) =', taylor(cos(x), 0, 4).subs(x,1))

print('e(1) =', taylor(exp(x), 0, 4).subs(x,1))
# Out:
# sin(1) = 5/6
# cos(1) = 1/2
# e(1) = 8/3

# %% [markdown]
# As we have all the necessary tools to visualize the results, let do it.

# %% [markdown]
# ##Taylor Expansion for Sine

# %%
# This will plot sine and its Taylor approximations
from sympy import series, Symbol
from sympy.functions import sin, cos, exp
from sympy.plotting import plot
import matplotlib.pyplot as plt

p = plot(sin(x),taylor(sin(x),0,1),taylor(sin(x),0,3),taylor(sin(x),0,5),
         (x,-3.5,3.5),legend=True, show=False, ylim=[-4,4])

p[0].line_color = 'blue'
p[1].line_color = 'green'
p[2].line_color = 'firebrick'
p[3].line_color = 'black'
p.title = 'Taylor Series Expansion for Sine'
p.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/sympy/plotting/plot.py:890: MatplotlibDeprecationWarning:
# The set_smart_bounds function was deprecated in Matplotlib 3.2 and will be removed two minor releases later.
#   self.ax.spines['left'].set_smart_bounds(True)
# /usr/local/lib/python3.6/dist-packages/sympy/plotting/plot.py:891: MatplotlibDeprecationWarning:
# The set_smart_bounds function was deprecated in Matplotlib 3.2 and will be removed two minor releases later.
#   self.ax.spines['bottom'].set_smart_bounds(False)

# %% [markdown]
# #Taylor Expansion for Cosine

# %%
# This will plot cosine and its Taylor approximations

p = plot(cos(x),taylor(cos(x),0,2),taylor(cos(x),0,4),taylor(cos(x),0,6),
         (x,-4.5,4.5),legend=True, show=False, ylim=[-7.5,7.5])

p[0].line_color = 'blue'
p[1].line_color = 'green'
p[2].line_color = 'firebrick'
p[3].line_color = 'black'
p.title = 'Taylor Series Expansion for Cosine'
p.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/sympy/plotting/plot.py:890: MatplotlibDeprecationWarning:
# The set_smart_bounds function was deprecated in Matplotlib 3.2 and will be removed two minor releases later.
#   self.ax.spines['left'].set_smart_bounds(True)
# /usr/local/lib/python3.6/dist-packages/sympy/plotting/plot.py:891: MatplotlibDeprecationWarning:
# The set_smart_bounds function was deprecated in Matplotlib 3.2 and will be removed two minor releases later.
#   self.ax.spines['bottom'].set_smart_bounds(False)

# %% [markdown]
# #Taylor Expansion for Exponent

# %%
# This will plot exponent and its Taylor approximations

p = plot(exp(x),taylor(exp(x),0,1),taylor(exp(x),0,2),taylor(exp(x),0,3),
         (x,-2,2),legend=True, show=False, ylim=[-1,7])

p[0].line_color = 'blue'
p[1].line_color = 'green'
p[2].line_color = 'firebrick'
p[3].line_color = 'black'
p.title = 'Taylor Series Expansion for Exponent'
p.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/sympy/plotting/plot.py:890: MatplotlibDeprecationWarning:
# The set_smart_bounds function was deprecated in Matplotlib 3.2 and will be removed two minor releases later.
#   self.ax.spines['left'].set_smart_bounds(True)
# /usr/local/lib/python3.6/dist-packages/sympy/plotting/plot.py:891: MatplotlibDeprecationWarning:
# The set_smart_bounds function was deprecated in Matplotlib 3.2 and will be removed two minor releases later.
#   self.ax.spines['bottom'].set_smart_bounds(False)

# %% [markdown]
# <img src="https://raw.githubusercontent.com/jortizsi/MetNumUN2020II/master/Grafica4Taylor.png"/>

# %% [markdown]
# # **Applying TaylorSymPy.ipynb (based on Taylor Series Expansion with Python from Data Science Fabric) for the functions in the Taylor Series figure below**

# %% [markdown]
# <img src="https://raw.githubusercontent.com/jortizsi/MetNumUN2020II/master/Grafica5Taylor.png"/>

# %% [markdown]
# ***

# %%
from sympy import series, Symbol
from sympy.functions import sin, cos, exp, log, ln
from sympy.plotting import plot
import matplotlib.pyplot as plt
# %matplotlib inline

plt.rcParams['figure.figsize'] = 13,10
plt.rcParams['lines.linewidth'] = 2

# %%
# Define symbol
x = Symbol('x')

# %%
# Function for Taylor Series Expansion

def taylor(function, x0, n):
    """
    Parameter "function" is our function which we want to approximate
    "x0" is the point where to approximate
    "n" is the order of approximation
    """
    return function.series(x,x0,n).removeO()

# %% [markdown]
# # 1. Applied to $e^x$

# %% [markdown]
# $$\sum_{k=0}^{\infty} \frac{x^k}{k!} (|x| < \infty)$$

# %% [markdown]
# Obteniendo la serie de taylor con Sympy

# %%
#Notacion de SymPy
print('e(x) =', taylor(exp(x), 0, 4))
# Out:
# e(x) = x**3/6 + x**2/2 + x + 1

# %% [markdown]
# Evaluando $f(x)$ con x=1

# %%
print('e(1) =', taylor(exp(x), 0, 4).subs(x,1))
# Out:
# e(1) = 8/3

# %% [markdown]
# Grafica comparativa entre la funcion real y algunas aproximaciones por series de taylor

# %%
# This will plot exponent and its Taylor approximations

p = plot(exp(x),taylor(exp(x),0,1),taylor(exp(x),0,2),taylor(exp(x),0,3),
         (x,-2,2),legend=True, show=False, ylim=[-1,7])

p[0].line_color = 'blue'
p[1].line_color = 'green'
p[2].line_color = 'firebrick'
p[3].line_color = 'black'
p.title = 'Taylor Series Expansion for Exponent'
p.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/sympy/plotting/plot.py:890: MatplotlibDeprecationWarning:
# The set_smart_bounds function was deprecated in Matplotlib 3.2 and will be removed two minor releases later.
#   self.ax.spines['left'].set_smart_bounds(True)
# /usr/local/lib/python3.6/dist-packages/sympy/plotting/plot.py:891: MatplotlibDeprecationWarning:
# The set_smart_bounds function was deprecated in Matplotlib 3.2 and will be removed two minor releases later.
#   self.ax.spines['bottom'].set_smart_bounds(False)

# %% [markdown]
# # 2. Applied to $sen(x)$

# %% [markdown]
# $$\sum_{k=0}^{\infty} (-1)^k \frac{x^{2k + 1}}{(2k + 1)!} (|x| < \infty)$$

# %% [markdown]
# Obteniendo la serie de taylor con Sympy

# %%
#Notacion de SymPy
print('sin(x) =', taylor(sin(x), 0, 4))
# Out:
# sin(x) = -x**3/6 + x

# %% [markdown]
# Evaluando $f(x)$ con x=1

# %%
print('sin(1) =', taylor(sin(x), 0, 4).subs(x,1))
# Out:
# sin(1) = 5/6

# %% [markdown]
# Grafica comparativa entre la funcion real y algunas aproximaciones por series de taylor

# %%
# This will plot sine and its Taylor approximations
from sympy import series, Symbol
from sympy.functions import sin, cos, exp
from sympy.plotting import plot
import matplotlib.pyplot as plt

p = plot(sin(x),taylor(sin(x),0,1),taylor(sin(x),0,3),taylor(sin(x),0,5),
         (x,-3.5,3.5),legend=True, show=False, ylim=[-4,4])

p[0].line_color = 'blue'
p[1].line_color = 'green'
p[2].line_color = 'firebrick'
p[3].line_color = 'black'
p.title = 'Taylor Series Expansion for Sine'
p.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/sympy/plotting/plot.py:890: MatplotlibDeprecationWarning:
# The set_smart_bounds function was deprecated in Matplotlib 3.2 and will be removed two minor releases later.
#   self.ax.spines['left'].set_smart_bounds(True)
# /usr/local/lib/python3.6/dist-packages/sympy/plotting/plot.py:891: MatplotlibDeprecationWarning:
# The set_smart_bounds function was deprecated in Matplotlib 3.2 and will be removed two minor releases later.
#   self.ax.spines['bottom'].set_smart_bounds(False)

# %% [markdown]
# # 3. Applied to $cos(x)$

# %% [markdown]
# $$\sum_{k=0}^{\infty} (-1)^k \frac{x^{2k}}{(2k)!} (|x| < \infty)$$

# %% [markdown]
# Obteniendo la serie de taylor con Sympy

# %%
#Notacion de SymPy
print('cos(x) =', taylor(cos(x), 0, 4))
# Out:
# cos(x) = -x**2/2 + 1

# %% [markdown]
# Evaluando $f(x)$ con x=1

# %%
print('cos(1) =', taylor(cos(x), 0, 4).subs(x,1))
# Out:
# cos(1) = 1/2

# %% [markdown]
# Grafica comparativa entre la funcion real y algunas aproximaciones por series de taylor

# %%
# This will plot cosine and its Taylor approximations

p = plot(cos(x),taylor(cos(x),0,2),taylor(cos(x),0,4),taylor(cos(x),0,6),
         (x,-4.5,4.5),legend=True, show=False, ylim=[-7.5,7.5])

p[0].line_color = 'blue'
p[1].line_color = 'green'
p[2].line_color = 'firebrick'
p[3].line_color = 'black'
p.title = 'Taylor Series Expansion for Cosine'
p.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/sympy/plotting/plot.py:890: MatplotlibDeprecationWarning:
# The set_smart_bounds function was deprecated in Matplotlib 3.2 and will be removed two minor releases later.
#   self.ax.spines['left'].set_smart_bounds(True)
# /usr/local/lib/python3.6/dist-packages/sympy/plotting/plot.py:891: MatplotlibDeprecationWarning:
# The set_smart_bounds function was deprecated in Matplotlib 3.2 and will be removed two minor releases later.
#   self.ax.spines['bottom'].set_smart_bounds(False)

# %% [markdown]
# # 4. Applied to $\frac{1}{1-x}$

# %% [markdown]
# $$\sum_{k=0}^{\infty} x^k (|x| < 1)$$

# %%
#Funcion real
def f_1_div_1minusx(x):
  return 1/(1-x)

# %% [markdown]
# Obteniendo la serie de taylor con Sympy

# %%
#Notacion de SymPy
print('1/(1-x) =', taylor(f_1_div_1minusx(x), 0, 4))
# Out:
# 1/(1-x) = x**3 + x**2 + x + 1

# %% [markdown]
# Evaluando $f(x)$ con x=0.9

# %%
print('[f(x) = 1/(1-x), x=0.9] =', taylor(f_1_div_1minusx(x), 0, 4).subs(x,0.9))
# Out:
# [f(x) = 1/(1-x), x=0.9] = 3.43900000000000

# %% [markdown]
# Grafica comparativa entre la funcion real y algunas aproximaciones por series de taylor

# %%
# This will plot sine and its Taylor approximations
from sympy import series, Symbol
from sympy.functions import sin, cos, exp
from sympy.plotting import plot
import matplotlib.pyplot as plt

p = plot(f_1_div_1minusx(x),taylor(f_1_div_1minusx(x),0,2),taylor(f_1_div_1minusx(x),0,4),taylor(f_1_div_1minusx(x),0,6),
         (x,-3,0.95),legend=True, show=False, ylim=[-7,7])

p[0].line_color = 'blue'
p[1].line_color = 'green'
p[2].line_color = 'firebrick'
p[3].line_color = 'black'
p.title = 'Taylor Series Expansion for 1/(1-x)'
p.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/sympy/plotting/plot.py:890: MatplotlibDeprecationWarning:
# The set_smart_bounds function was deprecated in Matplotlib 3.2 and will be removed two minor releases later.
#   self.ax.spines['left'].set_smart_bounds(True)
# /usr/local/lib/python3.6/dist-packages/sympy/plotting/plot.py:891: MatplotlibDeprecationWarning:
# The set_smart_bounds function was deprecated in Matplotlib 3.2 and will be removed two minor releases later.
#   self.ax.spines['bottom'].set_smart_bounds(False)

# %% [markdown]
# # 5. Applied to $ln(1+x)$

# %% [markdown]
# $$\sum_{k=1}^{\infty} (-1)^{k-1} \frac{x^k}{k} (-1< x \leq 1)$$

# %% [markdown]
# Obteniendo la serie de taylor con Sympy

# %%
#Notacion de SymPy
print('ln(1+x) =', taylor(log(1+x), 0, 4))
# Out:
# ln(1+x) = x**3/3 - x**2/2 + x

# %% [markdown]
# Evaluando $f(x)$ con x=0.5

# %%
print('[f(x) = ln(1+x), x=0.5] =', taylor(log(1+x), 0, 4).subs(x,0.5))
# Out:
# [f(x) = ln(1+x), x=0.5] = 0.416666666666667

# %% [markdown]
# Grafica comparativa entre la funcion real y algunas aproximaciones por series de taylor

# %%
# This will plot sine and its Taylor approximations
from sympy import series, Symbol
from sympy.functions import sin, cos, exp
from sympy.plotting import plot
import matplotlib.pyplot as plt

p = plot(log(1+x),taylor(log(1+x),0,2),taylor(log(1+x),0,3),taylor(log(1+x),0,6),
         (x,-0.95,1),legend=True, show=False, ylim=[-2,4])

p[0].line_color = 'blue'
p[1].line_color = 'green'
p[2].line_color = 'firebrick'
p[3].line_color = 'black'
p.title = 'Taylor Series Expansion for log(1+x)'
p.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/sympy/plotting/plot.py:890: MatplotlibDeprecationWarning:
# The set_smart_bounds function was deprecated in Matplotlib 3.2 and will be removed two minor releases later.
#   self.ax.spines['left'].set_smart_bounds(True)
# /usr/local/lib/python3.6/dist-packages/sympy/plotting/plot.py:891: MatplotlibDeprecationWarning:
# The set_smart_bounds function was deprecated in Matplotlib 3.2 and will be removed two minor releases later.
#   self.ax.spines['bottom'].set_smart_bounds(False)

# %% [markdown]
# # 6. Applied to $ln(x)$

# %% [markdown]
# $$\sum_{k=1}^{\infty} (-1)^{k-1} \frac{(x-1)^k}{k} (-1< x \leq 1)$$

# %% [markdown]
# Obteniendo la serie de taylor con Sympy

# %%
#Notacion de SymPy
print('ln(x) =', taylor(ln(x), 1, 4))
# Out:
# ln(x) = x + (x - 1)**3/3 - (x - 1)**2/2 - 1

# %% [markdown]
# Evaluando $f(x)$ con x=1

# %%
print('[f(x) = ln(x), x=0.5] =', taylor(ln(x), 1, 4).subs(x,0.5))
# Out:
# [f(x) = ln(x), x=0.5] = -0.666666666666667

# %% [markdown]
# Grafica comparativa entre la funcion real y algunas aproximaciones por series de taylor

# %%
# This will plot sine and its Taylor approximations
from sympy import series, Symbol
from sympy.functions import sin, cos, exp
from sympy.plotting import plot
import matplotlib.pyplot as plt

p = plot(log(x),taylor(log(x),1,1),taylor(ln(x),1,3),taylor(ln(x),1,5),
         (x,-0.4,1),legend=True, show=False, ylim=[-6,2])

p[0].line_color = 'blue'
p[1].line_color = 'green'
p[2].line_color = 'firebrick'
p[3].line_color = 'black'
p.title = 'Taylor Series Expansion for log(1+x)'
p.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/sympy/plotting/plot.py:890: MatplotlibDeprecationWarning:
# The set_smart_bounds function was deprecated in Matplotlib 3.2 and will be removed two minor releases later.
#   self.ax.spines['left'].set_smart_bounds(True)
# /usr/local/lib/python3.6/dist-packages/sympy/plotting/plot.py:891: MatplotlibDeprecationWarning:
# The set_smart_bounds function was deprecated in Matplotlib 3.2 and will be removed two minor releases later.
#   self.ax.spines['bottom'].set_smart_bounds(False)
